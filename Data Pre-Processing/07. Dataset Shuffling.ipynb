# %%
import pandas as pd
df = pd.read_csv('../Datasets/diabetes_two.csv')

# %% [markdown]
# <font color="orange"><h1><b>Shuffling Dataset

# %%
from sklearn.utils import shuffle

# %%
shuffled_df = shuffle(df)

# %%
shuffled_df
# Out:
#       Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 267  35.0  Female       No         No                 No       No         No
# 430  32.0    Male       No         No                 No       No         No
# 294  42.0    Male       No         No                 No       No         No
# 114  55.0  Female      Yes         No                Yes       No         No
# 259  62.0    Male      Yes         No                 No      Yes         No
# ..    ...     ...      ...        ...                ...      ...        ...
# 194  43.0    Male       No         No                Yes      Yes        Yes
# 260  33.0    Male       No        Yes                 No       No         No
# 503  44.0    Male       No         No                 No       No         No
# 408  59.0  Female       No         No                 No      Yes         No
# 109  39.0  Female      Yes        Yes                 No       No        Yes
#
# ...

# %% [markdown]
# <font color = "yellow">
# Rearranging index of the dataset

# %%
rearranged_df = shuffled_df.reset_index(drop=True)

# %%
rearranged_df
# Out:
#       Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0    35.0  Female       No         No                 No       No         No
# 1    32.0    Male       No         No                 No       No         No
# 2    42.0    Male       No         No                 No       No         No
# 3    55.0  Female      Yes         No                Yes       No         No
# 4    62.0    Male      Yes         No                 No      Yes         No
# ..    ...     ...      ...        ...                ...      ...        ...
# 515  43.0    Male       No         No                Yes      Yes        Yes
# 516  33.0    Male       No        Yes                 No       No         No
# 517  44.0    Male       No         No                 No       No         No
# 518  59.0  Female       No         No                 No      Yes         No
# 519  39.0  Female      Yes        Yes                 No       No        Yes
#
# ...
