# %%
import pandas as pd
df = pd.read_csv('../Datasets/diabetes_two.csv')

# %% [markdown]
# <h1><b><font color="lime">Handling Duplicate Samples</b></h1>

# %%
#finding the duplicates
duplicates = df[df.duplicated(keep='first')]
duplicates
# Out:
#       Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 84   35.0  Female      Yes        Yes                Yes      Yes        Yes
# 159  38.0  Female      Yes        Yes                Yes      Yes        Yes
# 160  28.0  Female       No         No                 No       No         No
# 161  68.0  Female      Yes        Yes                 No      Yes        Yes
# 162  35.0  Female       No         No                 No       No         No
# ..    ...     ...      ...        ...                ...      ...        ...
# 496  53.0    Male       No         No                 No      Yes         No
# 497  47.0    Male       No         No                 No       No         No
# 498  68.0  Female      Yes        Yes                 No      Yes        Yes
# 499  64.0    Male       No         No                 No      Yes        Yes
# 504  38.0    Male       No         No                 No       No         No
#
# ...

# %% [markdown]
# <font color = "yellow">
# (i) dropping duplicate samples

# %%
new_df = df.drop_duplicates()

# %%
#rechecking duplicates
duplicates = new_df[new_df.duplicated(keep='first')]
duplicates
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Polyuria, Polydipsia, sudden weight loss, weakness, Polyphagia, Genital thrush, visual blurring, Itching, Irritability, delayed healing, partial paresis, muscle stiffness, Alopecia, Obesity, class]
# Index: []

# %%
print('previous df size: ', len(df))
print('new df size: ', len(new_df))
# Out:
# previous df size:  520
# new df size:  252
